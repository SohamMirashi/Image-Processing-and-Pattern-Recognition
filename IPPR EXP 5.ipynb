# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read image
img = cv2.imread(r"C:\Users\Soham M\Desktop\B.Tech\IPPR\Image-Processing-and-Pattern-Recognition\cat-katze-black-white-black-and-white-preview.jpg", cv2.IMREAD_GRAYSCALE)

# Display image
plt.imshow(img, cmap='gray')
plt.title("Original Image")
plt.axis("off")
plt.show()

# %% [markdown]
# #### Sobel Edge detection (X direction)

# %%
sobelx = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=5)

plt.imshow(sobelx, cmap='gray')
plt.title("Sobel X Edge Detection")
plt.axis("off")
plt.show()

# %% [markdown]
# #### Sobel Edge detection (Y direction)

# %%
sobely = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=5)

plt.imshow(sobely, cmap='gray')
plt.title("Sobel Y Edge Detection")
plt.axis("off")
plt.show()

# %% [markdown]
# #### Sobel Edge detection (X & Y direction)

# %%
sobelxy = cv2.Sobel(img, cv2.CV_64F, 1, 1, ksize=5)

plt.imshow(sobelxy, cmap='gray')
plt.title("Sobel X + Y Edge Detection")
plt.axis("off")
plt.show()

# %% [markdown]
# #### Apply Laplacian operator

# %%
laplacian = cv2.Laplacian(img, cv2.CV_64F)

plt.imshow(laplacian, cmap='gray')
plt.title("Laplacian Edge Detection")
plt.axis("off")
plt.show()

# %% [markdown]
# #### Canny Edge detection

# %%
canny = cv2.Canny(img, 100, 200)

plt.imshow(canny, cmap='gray')
plt.title("Canny Edge Detection")
plt.axis("off")
plt.show()
